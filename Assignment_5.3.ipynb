# %%
import numpy as np
import pandas as pd

# %% [raw]
# #1. Create a sample JSON object from titanic dataset
#
# https://raw.githubusercontent.com/pcsanwald/kaggle-titanic/master/train.csv

# %%
csvObj = pd.read_csv('https://raw.githubusercontent.com/pcsanwald/kaggle-titanic/master/train.csv')
csvObj.head()
type(csvObj)
# Out:
# pandas.core.frame.DataFrame

# %%
jsonObj = csvObj.head(20).to_json()
jsonObj
type(jsonObj)
# Out:
# str

# %% [markdown]
# ## Read the JSON object and convert it to pandas data frame

# %%
df = pd.read_json(jsonObj)
df.head()
# Out:
#      age cabin embarked     fare  \
# 0   22.0  None        S   7.2500
# 1   38.0   C85        C  71.2833
# 10   4.0    G6        S  16.7000
# 11  58.0  C103        S  26.5500
# 12  20.0  None        S   8.0500
#
#                                                  name  parch  pclass     sex  \
# 0                             Braund, Mr. Owen Harris      0       3    male
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1  female
# 10                    Sandstrom, Miss. Marguerite Rut      1       3  female
# 11                           Bonnell, Miss. Elizabeth      0       1  female
# 12                     Saundercock, Mr. William Henry      0       3    male
#
#     sibsp  survived     ticket
# 0       1         0  A/5 21171
# 1       1         1   PC 17599
# 10      1         1    PP 9549
# 11      0         1     113783
# 12      0         0  A/5. 2151

# %% [raw]
# # match the top 5 records from JSON read and actual titanic dataset

# %% [raw]
# #2. read the HTML file as given below
# # http://vincentarelbundock.github.io/Rdatasets/datasets.html

# %%
htmlDataset = pd.read_html('http://vincentarelbundock.github.io/Rdatasets/datasets.html',header=0)
#htmlDataset[1]
htmlDf = pd.DataFrame(htmlDataset[1])
htmlDf
# Out:
#      Package          Item                                              Title  \
# 0       boot          acme                             Monthly Excess Returns
# 1       boot          aids       Delay in AIDS Reporting in England and Wales
# 2       boot     aircondit             Failures of Air-conditioning Equipment
# 3       boot    aircondit7             Failures of Air-conditioning Equipment
# 4       boot          amis                     Car Speeding and Warning Signs
# 5       boot           aml    Remission Times for Acute Myelogenous Leukaemia
# 6       boot        beaver                       Beaver Body Temperature Data
# 7       boot       bigcity                          Population of U.S. Cities
# 8       boot      brambles                  Spatial Location of Bramble Canes
# 9       boot       breslow                       Smoking Deaths Among Doctors
# 10      boot       calcium                                Calcium Uptake Data
# 11      boot          cane                            Sugar-cane Disease Data
# 12      boot    capability               Simulated Manufacturing Process Data
# 13      boot         catsM                      Weight Data for Domestic Cats
# 14      boot           cav                        Position of Muscle Caveolae
# 15      boot           cd4               CD4 Counts for HIV-Positive Patients
# 16      boot    cd4.nested                       Nested Bootstrap of cd4 data
# 17      boot      channing                                Channing House Data
# 18      boot          city                          Population of U.S. Cities
# 19      boot      claridge                   Genetic Links to Left-handedness
# 20      boot         cloth                           Number of Flaws in Cloth
# 21      boot   co.transfer                           Carbon Monoxide Transfer
# 22      boot          coal                     Dates of Coal Mining Disasters
# 23      boot        darwin                  Darwin's Plant Height Differences
# 24      boot          dogs                     Cardiac Data for Domestic Dogs
# 25      boot      downs.bc   Incidence of Down's Syndrome in British Columbia
# 26      boot         ducks  Behavioral and Plumage Characteristics of Hybr...
# 27      boot           fir                     Counts of Balsam-fir Seedlings
# 28      boot         frets                        Head Dimensions in Brothers
# 29      boot          grav                        Acceleration Due to Gravity
# ...      ...           ...                                                ...
# 1117   Zelig         free1                             Freedom of Speech Data
# 1118   Zelig         free2                             Freedom of Speech Data
# 1119   Zelig    friendship  Simulated Example of Schoolchildren Friendship...
# 1120   Zelig      grunfeld  Simulation Data for model Seemingly Unrelated ...
# 1121   Zelig          hoff                   Social Security Expenditure Data
# 1122   Zelig       homerun  Sample Data on Home Runs Hit By Mark McGwire a...
# 1123   Zelig         immi1     Individual Preferences Over Immigration Policy
# 1124   Zelig         immi2     Individual Preferences Over Immigration Policy
# 1125   Zelig         immi3     Individual Preferences Over Immigration Policy
# 1126   Zelig         immi4     Individual Preferences Over Immigration Policy
# 1127   Zelig         immi5     Individual Preferences Over Immigration Policy
# 1128   Zelig   immigration     Individual Preferences Over Immigration Policy
# 1129   Zelig         klein  Simulation Data for model Two-Stage Least Squa...
# 1130   Zelig        kmenta  Simulation Data for model Three-Stage Least Sq...
# 1131   Zelig         macro                                 Macroeconomic Data
# 1132   Zelig   MatchIt.url                           Table of links for Zelig
# 1133   Zelig        mexico  Voting Data from the 1988 Mexican Presidental ...
# 1134   Zelig           mid                    Militarized Interstate Disputes
# 1135   Zelig   newpainters         The Discretized Painter's Data of de Piles
# 1136   Zelig        PErisk  Political Economic Risk Data from 62 Countries...
# 1137   Zelig      sanction                    Multilateral Economic Sanctions
# 1138   Zelig     seatshare         Left Party Seat Share in 11 OECD Countries
# 1139   Zelig        sna.ex           Simulated Example of Social Network Data
# 1140   Zelig  SupremeCourt                     U.S. Supreme Court Vote Matrix
# 1141   Zelig         swiss  Swiss Fertility and Socioeconomic Indicators (...
# 1142   Zelig         tobin                                 Tobin's Tobit Data
# 1143   Zelig       turnout  Turnout Data Set from the National Election Su...
# 1144   Zelig    voteincome  Sample Turnout and Demographic Data from the 2...
# 1145   Zelig        Weimar                          1932 Weimar election data
# 1146   Zelig     Zelig.url                           Table of links for Zelig
#
#       Rows  Cols  CSV  Doc
# 0       60     3  CSV  DOC
# 1      570     6  CSV  DOC
# 2       12     1  CSV  DOC
# 3       24     1  CSV  DOC
# 4     8437     4  CSV  DOC
# 5       23     3  CSV  DOC
# 6      100     4  CSV  DOC
# 7       49     2  CSV  DOC
# 8      823     3  CSV  DOC
# 9       10     5  CSV  DOC
# 10      27     2  CSV  DOC
# 11     180     5  CSV  DOC
# 12      75     1  CSV  DOC
# 13      97     3  CSV  DOC
# 14     138     2  CSV  DOC
# 15      20     2  CSV  DOC
# 16     999     2  CSV  DOC
# 17     462     5  CSV  DOC
# 18      10     2  CSV  DOC
# 19      37     2  CSV  DOC
# 20      32     2  CSV  DOC
# 21       7     2  CSV  DOC
# 22     191     1  CSV  DOC
# 23      15     1  CSV  DOC
# 24       7     2  CSV  DOC
# 25      30     3  CSV  DOC
# 26      11     2  CSV  DOC
# 27      50     3  CSV  DOC
# 28      25     4  CSV  DOC
# 29      26     2  CSV  DOC
# ...    ...   ...  ...  ...
# 1117   450    11  CSV  DOC
# 1118   450    11  CSV  DOC
# 1119     0     7  CSV  DOC
# 1120    20     7  CSV  DOC
# 1121    36     5  CSV  DOC
# 1122   314     5  CSV  DOC
# 1123  2485     5  CSV  DOC
# 1124  2485     5  CSV  DOC
# 1125  2485     5  CSV  DOC
# 1126  2485     5  CSV  DOC
# 1127  2485     5  CSV  DOC
# 1128  2485     5  CSV  DOC
# 1129    21    14  CSV  DOC
# 1130    20     5  CSV  DOC
# 1131   350     6  CSV  DOC
# 1132     2     2  CSV  DOC
# 1133  1359    33  CSV  DOC
# 1134  3126     7  CSV  DOC
# 1135    54     4  CSV  DOC
# 1136    62     6  CSV  DOC
# 1137    78     8  CSV  DOC
# 1138   384     4  CSV  DOC
# 1139     0     5  CSV  DOC
# 1140    43     9  CSV  DOC
# 1141    47     6  CSV  DOC
# 1142    20     3  CSV  DOC
# 1143  2000     5  CSV  DOC
# 1144  1500     7  CSV  DOC
# 1145    10    11  CSV  DOC
# 1146    49     2  CSV  DOC
#
# [1147 rows x 7 columns]
